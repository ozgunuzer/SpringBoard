# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
#from library.sb_utils import save_file
import datetime as dt
import string

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
alphabet = list(string.ascii_lowercase)
#alphabet

# %%
# Take the 2 years of data into pandas dataframe and name them
# start from March 2019 data
sf1 = pd.read_csv('listings319.csv')
sf2 = pd.read_csv('listings419.csv')
sf3 = pd.read_csv('listings519.csv')
sf4 = pd.read_csv('listings619.csv')
sf5 = pd.read_csv('listings719.csv')
sf6 = pd.read_csv('listings819.csv')
sf7 = pd.read_csv('listings919.csv')
sf8 = pd.read_csv('listings1019.csv')
sf9 = pd.read_csv('listings1119.csv')
sf10 = pd.read_csv('listings1219.csv')
# 2020 data starting from January
sf11 = pd.read_csv('listings120.csv')
sf12 = pd.read_csv('listings220.csv')
sf13 = pd.read_csv('listings320.csv')
sf14 = pd.read_csv('listings420.csv')
sf15 = pd.read_csv('listings520.csv')
sf16 = pd.read_csv('listings620.csv')
sf17 = pd.read_csv('listings720.csv')
sf18 = pd.read_csv('listings820.csv')
sf19 = pd.read_csv('listings920.csv')
sf20 = pd.read_csv('listings1020.csv')
sf21 = pd.read_csv('listings1120.csv')
sf22 = pd.read_csv('listings1220.csv')
# 2021 data until march
sf23 = pd.read_csv('listings121.csv')
sf24 = pd.read_csv('listings221.csv')
sf25 = pd.read_csv('listings321.csv')

# %%
# Took San Francisco (SF) airbnb data for 2 years into 25 different pandas data frames. We see that there is no date
# column that should show the scrape date
sf1.head()
# Out:
#      id                                               name  host_id  \
# 0   958                Bright, Modern Garden Unit - 1BR/1B     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 4  8339                    Historic Alamo Square Victorian    24215
#
#           host_name  neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                  NaN  Western Addition  37.76931
# 1  Philip And Tania                  NaN    Bernal Heights  37.74511
# 2             Aaron                  NaN    Haight Ashbury  37.76669
# 3             Aaron                  NaN    Haight Ashbury  37.76487
# 4              Rosy                  NaN  Western Addition  37.77525
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
#Even if adding dates like this looks like extra work which can be dealt with a for loop, I preferred to do it like this 
# for future referance and to keep track of the data
sf1['date'] = pd.to_datetime('01-March-2019')
sf2['date'] = pd.to_datetime('01-April-2019')
sf3['date'] = pd.to_datetime('01-May-2019')
sf4['date'] = pd.to_datetime('01-June-2019')
sf5['date'] = pd.to_datetime('01-July-2019')
sf6['date'] = pd.to_datetime('01-August-2019')
sf7['date'] = pd.to_datetime('01-September-2019')
sf8['date'] = pd.to_datetime('01-October-2019')
sf9['date'] = pd.to_datetime('01-November-2019')
sf10['date'] = pd.to_datetime('01-December-2019')
# 2020 data starting from January
sf11['date'] = pd.to_datetime('01-January-2020')
sf12['date'] = pd.to_datetime('01-February-2020')
sf13['date'] = pd.to_datetime('01-March-2020')
sf14['date'] = pd.to_datetime('01-April-2020')
sf15['date'] = pd.to_datetime('01-May-2020')
sf16['date'] = pd.to_datetime('01-June-2020')
sf17['date'] = pd.to_datetime('01-July-2020')
sf18['date'] = pd.to_datetime('01-August-2020')
sf19['date'] = pd.to_datetime('01-September-2020')
sf20['date'] = pd.to_datetime('01-October-2020')
sf21['date'] = pd.to_datetime('01-November-2020')
sf22['date'] = pd.to_datetime('01-December-2020')
# 2021 data until march
sf23['date'] = pd.to_datetime('01-January-2021')
sf24['date'] = pd.to_datetime('01-February-2021')
sf25['date'] = pd.to_datetime('01-March-2021')

# %%
sf1.head()
# Out:
#      id                                               name  host_id  \
# 0   958                Bright, Modern Garden Unit - 1BR/1B     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 4  8339                    Historic Alamo Square Victorian    24215
#
#           host_name  neighbourhood_group     neighbourhood  latitude  \
# 0             Holly                  NaN  Western Addition  37.76931
# 1  Philip And Tania                  NaN    Bernal Heights  37.74511
# 2             Aaron                  NaN    Haight Ashbury  37.76669
# 3             Aaron                  NaN    Haight Ashbury  37.76487
# 4              Rosy                  NaN  Western Addition  37.77525
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
sf25.date.unique()
# Out:
# array(['2021-03-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
sf1.shape
# Out:
# (7151, 17)

# %%
sf2.shape
# Out:
# (7277, 17)

# %%
sf25.shape
# Out:
# (6883, 17)

# %%
# When we check the shapes we see that the column names will be the same but there will be some airbnbs missing
sf1.id.nunique()
# Out:
# 7151

# %%
sf25.id.nunique()
# Out:
# 6883

# %%
# we check the missing data for sf1 (March 19 data). In the neighbourhood_group column, the data seems like missing
# for all the rows. We will try to see if we can fill these with other datasets
missing = pd.DataFrame([sf1.isnull().sum(), 100 * sf1.isnull().mean()]).transpose()
missing
# Out:
#                                      0           1
# id                                 0.0    0.000000
# name                               0.0    0.000000
# host_id                            0.0    0.000000
# host_name                          0.0    0.000000
# neighbourhood_group             7151.0  100.000000
# neighbourhood                      0.0    0.000000
# latitude                           0.0    0.000000
# longitude                          0.0    0.000000
# room_type                          0.0    0.000000
# price                              0.0    0.000000
# minimum_nights                     0.0    0.000000
# number_of_reviews                  0.0    0.000000
# last_review                     1377.0   19.256048
# reviews_per_month               1377.0   19.256048
# calculated_host_listings_count     0.0    0.000000
# availability_365                   0.0    0.000000
# date                               0.0    0.000000

# %%
missing25 = pd.DataFrame([sf25.isnull().sum(), 100 * sf25.isnull().mean()]).transpose()
missing25
# Looks like neighbourhood group is missing here as well
# Out:
#                                      0           1
# id                                 0.0    0.000000
# name                               0.0    0.000000
# host_id                            0.0    0.000000
# host_name                         15.0    0.217928
# neighbourhood_group             6883.0  100.000000
# neighbourhood                      0.0    0.000000
# latitude                           0.0    0.000000
# longitude                          0.0    0.000000
# room_type                          0.0    0.000000
# price                              0.0    0.000000
# minimum_nights                     0.0    0.000000
# number_of_reviews                  0.0    0.000000
# last_review                     1694.0   24.611361
# reviews_per_month               1694.0   24.611361
# calculated_host_listings_count     0.0    0.000000
# availability_365                   0.0    0.000000
# date                               0.0    0.000000

# %%
missing12 = pd.DataFrame([sf12.isnull().sum(), 100 * sf12.isnull().mean()]).transpose()
missing12
# Out:
#                                      0           1
# id                                 0.0    0.000000
# name                               0.0    0.000000
# host_id                            0.0    0.000000
# host_name                          0.0    0.000000
# neighbourhood_group             8587.0  100.000000
# neighbourhood                      0.0    0.000000
# latitude                           0.0    0.000000
# longitude                          0.0    0.000000
# room_type                          0.0    0.000000
# price                              0.0    0.000000
# minimum_nights                     0.0    0.000000
# number_of_reviews                  0.0    0.000000
# last_review                     1991.0   23.186212
# reviews_per_month               1991.0   23.186212
# calculated_host_listings_count     0.0    0.000000
# availability_365                   0.0    0.000000
# date                               0.0    0.000000

# %%
# Now we see that column named neighbourhood group might be dropped

# %%
## Let's merge the data and see how it changes

# %%
print('shape', sf1.shape, 'number of unique ids', sf1.id.nunique())
print('shape', sf2.shape,'number of unique ids',sf2.id.nunique())
# Out:
# shape (7151, 17) number of unique ids 7151
# shape (7277, 17) number of unique ids 7277

# %%
data1 = pd.merge(sf1,sf2,how='inner',on = 'id')

# %%
print('shape', data1.shape,'number of unique ids',data1.id.nunique())
# We have 7151 - 6779 = 372 and 7277 - 6779 = 498 different ids for sf1 and sf2
# Out:
# shape (6779, 33) number of unique ids 6779

# %%
# Here we can see that we will lose some data from each merge. Rather than losing data, I will keep all data 
# and try to see if I can make use of the price and attribute relationship even if the id is not the same 
# So I will concat the data
data2 = pd.concat([sf1,sf2])

# %%
print('shape', data2.shape,'number of unique ids',data2.id.nunique())
# Out:
# shape (14428, 17) number of unique ids 7649

# %%
# when we look at the unique ids 6779+498+372 = 7649. so the number holds.

# %%
dt19 = pd.concat([sf1,sf2,sf3,sf4,sf5,sf6,sf7,sf8,sf9,sf10])

# %%
print('shape', dt19.shape,'number of unique ids',dt19.id.nunique())
# Out:
# shape (78185, 17) number of unique ids 10901

# %%
print(min(dt19.date),max(dt19.date))
# Out:
# 2019-03-01 00:00:00 2019-12-01 00:00:00

# %%
# 2019 data is ready with 21781 rows and 8021 unique ids

# %%
dt20 = pd.concat([sf11,sf12,sf13,sf14,sf15,sf16,sf17,sf18,sf19,sf20,sf21,sf22])

# %%
print('shape', dt20.shape,'number of unique ids', dt20.id.nunique())
# Out:
# shape (92833, 17) number of unique ids 11437

# %%
print(min(dt20.date),max(dt20.date))
# Out:
# 2020-01-01 00:00:00 2020-12-01 00:00:00

# %%
dt21 = pd.concat([sf23,sf24,sf25])

# %%
print(min(dt21.date),max(dt21.date))
# Out:
# 2021-01-01 00:00:00 2021-03-01 00:00:00

# %%
print('shape', dt21.shape,'number of unique ids', dt21.id.nunique())
# Out:
# shape (20816, 17) number of unique ids 7378

# %%
# In 2020 the number of unique ids have increased(2019 - 10902, 2020 - 11437, 2021 - 7378). 
# This can be due to covid since many people started working remotely.
# They might have chosen to rent their rooms/homes in airbnb. If so this should have effected the prices 
# since the demand also might have gone down due to covid effect

# %%
# Lets put the main dataframe together
# This will be our main dataframe with all the data we have
dt = pd.concat([dt19, dt20, dt21])

# %%
print('shape', dt.shape,'number of unique ids', dt.id.nunique())
# Out:
# shape (191834, 17) number of unique ids 14001

# %%
missing_dt = pd.DataFrame([dt.isnull().sum(), 100 * dt.isnull().mean()]).transpose()
missing_dt
# Out:
#                                        0           1
# id                                   0.0    0.000000
# name                                 0.0    0.000000
# host_id                              0.0    0.000000
# host_name                          100.0    0.052128
# neighbourhood_group             191834.0  100.000000
# neighbourhood                        0.0    0.000000
# latitude                             0.0    0.000000
# longitude                            0.0    0.000000
# room_type                            0.0    0.000000
# price                                0.0    0.000000
# minimum_nights                       0.0    0.000000
# number_of_reviews                    0.0    0.000000
# last_review                      42429.0   22.117560
# reviews_per_month                42429.0   22.117560
# calculated_host_listings_count       0.0    0.000000
# availability_365                     0.0    0.000000
# date                                 0.0    0.000000

# %%
# since all the values for neighbourhood group is missing, we need to drop that column. 
# reviews are also our other problematic columns with 22% missing values

# %%
dt = dt.drop(columns = 'neighbourhood_group')

# %%
dt.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'date'],
#       dtype='object')

# %%
dt.shape
# Out:
# (191834, 16)

# %%
# Now we check the reviews that are missing

# %%
dt[dt.isnull().any(axis=1)]
# Out:
#             id                                               name    host_id  \
# 183     220780         Room in home near beach San  Francisco, Ca    1144980
# 262     364023   Beautiful, spacious, modern apt with great views    1789039
# 413     686677                Shared room with bathroom 1 person.    3503605
# 415     690872                          Pacific Hts Designer Home    1142106
# 476     819856                           Most Luxury condo in SF!    3752142
# ...        ...                                                ...        ...
# 6878  48369690                        Studio bernal San Francisco  389015392
# 6879  48375203      Room in Top Floor Remodeled Flat w/ HUGE DECK    2238981
# 6880  48380336  Luxury Room w/ TV,  workstation & rooftop balcony    6231463
# 6881  48381461              Hayes Valley 2 BR 2 BA w Rooftop Deck    1257432
# 6882  48382323  Heart of Downtown San Francisco Wyndham Canter...  199349788
#
# ...

# %%
temp = dt[dt.last_review.isnull()]
temp.number_of_reviews.unique()
# Out:
# array([0])

# %%
# We see that missing values in columns last review and reviews per months is bc these listings did not get any reviews

# %%
## NOW LETS CHECH CATEGORICAL VARIABLES

# %%
cat_var = dt.select_dtypes(include = ['object'])

# %%
cat_var.columns
# Out:
# Index(['name', 'host_name', 'neighbourhood', 'room_type', 'last_review'], dtype='object')

# %%
# now we check if there are any duplicates

# %%
dupes = dt[dt.duplicated() == True]
dupes
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, date]
# Index: []

# %%
# lets dig into the neighbourhoods

# %%
dt.neighbourhood.unique()
# Out:
# array(['Western Addition', 'Bernal Heights', 'Haight Ashbury', 'Mission',
#        'Potrero Hill', 'Downtown/Civic Center', 'Castro/Upper Market',
#        'Inner Sunset', 'South of Market', 'Noe Valley', 'Nob Hill',
#        'Outer Richmond', 'Presidio Heights', 'Glen Park', 'Ocean View',
#        'Pacific Heights', 'Financial District', 'Twin Peaks',
#        'Russian Hill', 'Outer Sunset', 'North Beach', 'Marina',
#        'Inner Richmond', 'Excelsior', 'Seacliff', 'Chinatown',
#        'West of Twin Peaks', 'Bayview', 'Diamond Heights',
#        'Outer Mission', 'Parkside', 'Lakeshore', 'Crocker Amazon',
#        'Golden Gate Park', 'Visitacion Valley', 'Presidio',
#        'Treasure Island/YBI'], dtype=object)

# %%
(dt.groupby(by = 'room_type')['neighbourhood'].value_counts())
# Out:
# room_type        neighbourhood
# Entire home/apt  South of Market          11210
#                  Mission                  11034
#                  Western Addition          8742
#                  Downtown/Civic Center     7200
#                  Castro/Upper Market       6997
#                                           ...
# Shared room      Lakeshore                   23
#                  Bernal Heights              20
#                  Excelsior                   15
#                  Treasure Island/YBI          4
#                  Glen Park                    2
# Name: neighbourhood, Length: 117, dtype: int64
