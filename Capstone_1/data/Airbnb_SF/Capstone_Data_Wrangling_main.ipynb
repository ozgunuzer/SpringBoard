# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
#from library.sb_utils import save_file
import datetime

# %%
pwd
# Out:
# '/Users/ozgunuzer/Desktop/SB-Projects/Capstone/data/Airbnb_SF'

# %%
sf = pd.read_csv('listings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-61071a0b12ce> in <module>
# ----> 1 sf = pd.read_csv('listings.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
sf_jan.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20210108081038   2021-01-10
# 1  5858  https://www.airbnb.com/rooms/5858  20210108081038   2021-01-10
# 2  7918  https://www.airbnb.com/rooms/7918  20210108081038   2021-01-10
# 3  8142  https://www.airbnb.com/rooms/8142  20210108081038   2021-01-09
# 4  8339  https://www.airbnb.com/rooms/8339  20210108081038   2021-01-09
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          description  \
# 0  Due to city restrictions, out of state visitor...
# 1  <b>The space</b><br />We live in a large Victo...
# ...

# %%
sf_jan.shape
# Out:
# (7002, 74)

# %%
sf_jan.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
# Here we can see that there are 74 columns in total. Some of them will not be very relevant to our analysis.
# So, we need to drop some of these.

# %%
sf_jan = sf_jan.drop(columns = ['listing_url', 'scrape_id', 'last_scraped','description','picture_url', 'host_url',
                               'host_name', 'host_since', 'host_location', 'host_about','host_thumbnail_url', 'host_picture_url',
                               'host_identity_verified','neighbourhood_cleansed', 'neighbourhood_group_cleansed','bathrooms_text',
                               'minimum_minimum_nights','maximum_minimum_nights', 'minimum_maximum_nights','maximum_maximum_nights', 'minimum_nights_avg_ntm',
                               'maximum_nights_avg_ntm', 'calendar_updated', 'calendar_last_scraped','number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
                               'last_review','review_scores_communication', 'review_scores_location','review_scores_value', 'license', 'instant_bookable',
                                'calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms',
                                'calculated_host_listings_count_shared_rooms','host_response_time','host_response_rate',
                               'host_acceptance_rate','host_verifications', 'host_has_profile_pic','neighborhood_overview','name'])

# %%
sf_jan.columns
# Out:
# Index(['id', 'host_id', 'host_is_superhost', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count', 'neighbourhood',
#        'latitude', 'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights',
#        'maximum_nights', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'reviews_per_month'],
#       dtype='object')

# %%
sf_jan.shape
# Out:
# (7002, 30)

# %%
sf_jan.head()
# Out:
#      id  host_id host_is_superhost host_neighbourhood  host_listings_count  \
# 0   958     1169                 t    Duboce Triangle                  1.0
# 1  5858     8904                 f     Bernal Heights                  2.0
# 2  7918    21994                 f        Cole Valley                 10.0
# 3  8142    21994                 f        Cole Valley                 10.0
# 4  8339    24215                 f       Alamo Square                  2.0
#
#    host_total_listings_count                             neighbourhood  \
# 0                        1.0  San Francisco, California, United States
# 1                        2.0  San Francisco, California, United States
# 2                       10.0  San Francisco, California, United States
# 3                       10.0                                       NaN
# 4                        2.0                                       NaN
#
#    latitude  longitude              property_type  ... availability_30  \
# ...

# %%
sf_jan.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  7.002000e+03  7.002000e+03          7001.000000
# mean   2.442286e+07  7.531051e+07            67.188116
# std    1.492465e+07  9.885241e+07           263.068369
# min    9.580000e+02  4.700000e+02             0.000000
# 25%    1.084497e+07  4.430421e+06             1.000000
# 50%    2.496845e+07  2.292746e+07             2.000000
# 75%    3.821882e+07  1.074344e+08            13.000000
# max    4.751510e+07  3.832662e+08          2646.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                7001.000000  7002.000000  7002.000000   7002.000000
# mean                   67.188116    37.768117  -122.429205      3.078406
# std                   263.068369     0.022936     0.026690      1.855283
# min                     0.000000    37.708250  -122.511630      1.000000
# 25%                     1.000000    37.753065  -122.441582      2.000000
# ...

# %%
covid = pd.read_csv('us-counties_covid.csv')

# %%
covid.head()
# Out:
#          date   county    state    fips  cases  deaths  confirmed_cases  \
# 0  2021-03-14  Autauga  Alabama  1001.0   6416    95.0           5527.0
# 1  2021-03-14  Baldwin  Alabama  1003.0  20091   294.0          14243.0
# 2  2021-03-14  Barbour  Alabama  1005.0   2181    53.0           1220.0
# 3  2021-03-14     Bibb  Alabama  1007.0   2479    58.0           2012.0
# 4  2021-03-14   Blount  Alabama  1009.0   6288   129.0           4838.0
#
#    confirmed_deaths  probable_cases  probable_deaths
# 0              85.0           889.0             10.0
# 1             220.0          5848.0             74.0
# 2              36.0           961.0             17.0
# 3              34.0           467.0             24.0
# 4             109.0          1450.0             20.0

# %%
covid.shape
# Out:
# (3247, 10)

# %%
covid = covid.loc[covid.state == 'California']

# %%
covid.head()
# Out:
#            date     county       state    fips  cases  deaths  \
# 186  2021-03-14    Alameda  California  6001.0  81990  1325.0
# 187  2021-03-14     Alpine  California  6003.0     82     0.0
# 188  2021-03-14     Amador  California  6005.0   3502    44.0
# 189  2021-03-14      Butte  California  6007.0  11126   184.0
# 190  2021-03-14  Calaveras  California  6009.0   1916    49.0
#
#      confirmed_cases  confirmed_deaths  probable_cases  probable_deaths
# 186          81990.0            1325.0             NaN              NaN
# 187             82.0               0.0             NaN              NaN
# 188           3502.0              44.0             NaN              NaN
# 189          11126.0             184.0             NaN              NaN
# 190           1916.0              49.0             NaN              NaN

# %%
covid.shape
# Out:
# (58, 10)

# %%
covid.date.unique()
# Out:
# array(['2021-03-14'], dtype=object)

# %%
covid.county.unique()
# Out:
# array(['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba'], dtype=object)

# %%
sf_jan.neighbourhood.unique()
# Out:
# array(['San Francisco, California, United States', nan,
#        'San Francisco, Hayes Valley, California, United States',
#        'Noe Valley - San Francisco, California, United States',
#        'Daly City, California, United States',
#        'San Franscisco, California, United States',
#        'San Jose, California, United States',
#        'San Francisco , Ca, United States'], dtype=object)

# %%
covid = covid[covid.county == 'San Francisco']

# %%
covid.county.unique()
# Out:
# array(['San Francisco'], dtype=object)

# %%
covid
# Out:
#            date         county       state    fips  cases  deaths  \
# 223  2021-03-14  San Francisco  California  6075.0  34761   452.0
#
#      confirmed_cases  confirmed_deaths  probable_cases  probable_deaths
# 223          34761.0             452.0             NaN              NaN

# %%
# back to sf airbnb january data
sf_jan.head()
# Out:
#      id  host_id host_is_superhost host_neighbourhood  host_listings_count  \
# 0   958     1169                 t    Duboce Triangle                  1.0
# 1  5858     8904                 f     Bernal Heights                  2.0
# 2  7918    21994                 f        Cole Valley                 10.0
# 3  8142    21994                 f        Cole Valley                 10.0
# 4  8339    24215                 f       Alamo Square                  2.0
#
#    host_total_listings_count                             neighbourhood  \
# 0                        1.0  San Francisco, California, United States
# 1                        2.0  San Francisco, California, United States
# 2                       10.0  San Francisco, California, United States
# 3                       10.0                                       NaN
# 4                        2.0                                       NaN
#
#    latitude  longitude              property_type  ... availability_30  \
# ...

# %%
# Since we will try to understand the price lets take a look at the price column
sf_jan.price.describe()
# Out:
# count        7002
# unique        579
# top       $150.00
# freq          169
# Name: price, dtype: object

# %%
missing = pd.DataFrame([sf_jan.isnull().sum(), 100 * sf_jan.isnull().mean()]).transpose()
missing.columns=['count', '%']
#missing.concat(by = ['count', '%'])
missing.sort_values(by = 'count')
# Out:
#                             count           %
# id                            0.0    0.000000
# minimum_nights                0.0    0.000000
# price                         0.0    0.000000
# amenities                     0.0    0.000000
# availability_30               0.0    0.000000
# availability_60               0.0    0.000000
# availability_90               0.0    0.000000
# accommodates                  0.0    0.000000
# room_type                     0.0    0.000000
# property_type                 0.0    0.000000
# longitude                     0.0    0.000000
# latitude                      0.0    0.000000
# availability_365              0.0    0.000000
# number_of_reviews             0.0    0.000000
# host_id                       0.0    0.000000
# maximum_nights                0.0    0.000000
# has_availability              0.0    0.000000
# host_total_listings_count     1.0    0.014282
# host_listings_count           1.0    0.014282
# ...

# %%
# Here the host neighboourhood is not relevant so it can be droppped
# bedrooms has 878 missing values
# review related fields has around 1700 missing values which might indicate that these are new listings
## Bathrooms are all missing. This column is improtant since having a shared bathroom will make a difference with a
# private bathroom

# %%
sf_jan.bathrooms
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 6997   NaN
# 6998   NaN
# 6999   NaN
# 7000   NaN
# 7001   NaN
# Name: bathrooms, Length: 7002, dtype: float64
